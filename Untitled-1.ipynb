# %%
class Student:
    school_name = "UPES"
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Aman", 20)
s2 = Student("Riya", 21)

print("School1 :", s1.school_name)
print("School1 :", s2.school_name)

print("Student 1", s1.name, s1.age)
print("Student 2", s2.name, s2.age)
# Out:
# School1 : UPES
# School1 : UPES
# Student 1 Aman 20
# Student 2 Riya 21

# %%
# Q4 Public and Private Data Members

class BankAccount:
    
    def __init__(self, name, balance):
        self.name = name          # public variable
        self.__balance = balance  # private variable

    def deposit(self, amount):
        self.__balance += amount
        print(amount, "deposited successfully")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(amount, "withdrawn successfully")
        else:
            print("Insufficient balance")

    def show_balance(self):
        print("Account Holder:", self.name)
        print("Balance:", self.__balance)


# creating object
b1 = BankAccount("Aman", 10000)

# testing methods
b1.show_balance()
b1.deposit(5000)
b1.show_balance()
b1.withdraw(3000)
b1.show_balance()
b1.withdraw(15000)
b1.show_balance()
# Out:
# Account Holder: Aman
# Balance: 10000
# 5000 deposited successfully
# Account Holder: Aman
# Balance: 15000
# 3000 withdrawn successfully
# Account Holder: Aman
# Balance: 12000
# Insufficient balance
# Account Holder: Aman
# Balance: 12000

# %%
# Q 3
class MathHelper :

    @staticmethod
    def is_even(num):
        return num % 2 == 0
    
print(MathHelper.is_even(8))
print(MathHelper.is_even(11))
# Out:
# True
# False

# %%
# Q5 Built-in Class Attributes

class Student:
    """This is a Student class used to demonstrate built-in attributes."""
    pass


print("Class Name:", Student.__name__)
print("Docstring:", Student.__doc__)
print("Module Name:", Student.__module__)
print("Class Dictionary:", Student.__dict__)
# Out:
# Class Name: Student
# Docstring: This is a Student class used to demonstrate built-in attributes.
# Module Name: __main__
# Class Dictionary: {'__module__': '__main__', '__doc__': 'This is a Student class used to demonstrate built-in attributes.', '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}

# %%
# Q6 Magic Methods / Operator Overloading

class Product:
    
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"Product: {self.name}, Price: {self.price}"

    def __add__(self, other):
        return self.price + other.price

    def __eq__(self, other):
        return self.price == other.price


# creating objects
p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)

# printing output
print(p1)
print(p1 + p2)
print(p1 == p3)
print(p1 == p2)
# Out:
# Product: Laptop, Price: 50000
# 80000
# True
# False

# %%
# Q2 Instance Method and Class Method

class Employee:
    company = "ABC Ltd"   # class variable

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def show_details(self):   # instance method
        print("Name:", self.name)
        print("Salary:", self.salary)
        print("Company:", Employee.company)

    @classmethod
    def change_company(cls, new_name):   # class method
        cls.company = new_name


# creating objects
e1 = Employee("Amit", 40000)
e2 = Employee("Neha", 50000)

print("Before changing company:")
e1.show_details()
print()
e2.show_details()

# changing company name
Employee.change_company("XYZ Pvt Ltd")

print("\nAfter changing company:")
e1.show_details()
print()
e2.show_details()
# Out:
# Before changing company:
# Name: Amit
# Salary: 40000
# Company: ABC Ltd
#
# Name: Neha
# Salary: 50000
# Company: ABC Ltd
#
# After changing company:
# Name: Amit
# Salary: 40000
# Company: XYZ Pvt Ltd
#
# Name: Neha
# Salary: 50000
# Company: XYZ Pvt Ltd
